# %%
import h5py
import numpy as np
from matplotlib import pyplot as plt

import tensorflow as tf
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Input,Dense,Conv1D,MaxPooling1D,UpSampling1D,Flatten,add
from tensorflow.keras.callbacks import ModelCheckpoint

from AD_tools import * # specifically need training()

# %%
plt.rcParams.update({
    'figure.figsize': (6,5),
    'font.size': 16,
    })

# %%
name = "2-0"

# %%
data = np.loadtxt("data/dataD10s_cut03.txt")
data.shape
# Out:
# (400, 43)

# %%
xx, yy = data[:,0], data[:,1]

# %%
sorter = np.argsort(xx)
xx, yy = xx[sorter], yy[sorter]

# %%
x_data = data[:,3:][sorter]

# %%
plt.plot(x_data[0],".--")
plt.plot(x_data[-1],"x--")

# %%
x_test = x_data.reshape((x_data.shape[0],4,10)).transpose((0,2,1))
x_test.shape
# Out:
# (400, 10, 4)

# %%
x_test = x_test[:,1:,:]
x_test.shape
# Out:
# (400, 9, 4)

# %%
shape_ = x_test.shape[1:]

# %%
plt.plot(x_test[0,:,0],".--")
plt.plot(x_test[-1,:,0],"x--")

# %%
def picker(fillings, fmin, fmax):
    fillings = np.array(fillings)
    pickle = np.where((fillings>= fmin) & (fillings <= fmax))
    return pickle, fillings[pickle]

# %%
rate=0.2 # Dropout percentage
bottleneck = 50 # latent space dimension, does not make great differences
fully = True

# %%
def cnnx(loss,optimizer,activation0,activation,x_shape,dim1=(16,(3,)),dim2=(16,(3,)), fully=False):
    """ 
    Pretty Standard Convolutional Autoencoder with a fully-connected latent space
    activation0: Activations "inside" the CAE
    activation: Last activation (important depending on the range of the pixel values)
    """
    in_dim = x_shape
    input_img = Input(shape=in_dim)
   
    #x1 = Conv1D(*dim1, activation=activation0, padding='same')(input_img)
    #x2 = MaxPooling1D((2,), padding='same')(x1)
    #x2 = Conv1D(*dim2, activation=activation0, padding='same')(x2)
    #x3 = MaxPooling1D((2,), padding='same')(x2)
    #encoded = Conv1D(*dim2, activation=activation0, padding='same')(x2)
    
    encoded = Flatten()(input_img)
    encoded = Dense(units=100,activation=activation0)(encoded)
    encoded = tf.keras.layers.Dropout(rate)(encoded)
    encoded = Dense(units=25,activation=activation0)(encoded)
    
    y = Dense(units=100,activation=activation0)(encoded)
    y = tf.keras.layers.Dropout(rate)(y)

    #y=UpSampling1D(2)(encoded)
    #y=Conv1D(*dim1, activation=activation0, padding='same')(y)
    #y=UpSampling1D(2)(y)
    decoded = Dense(np.prod(in_dim), activation=activation)(y)
    decoded = tf.keras.layers.Reshape(in_dim)(decoded)
    

    cnn = Model(input_img, decoded)
    cnn.compile(loss=loss,optimizer=optimizer)
    return cnn

# %%
# Show Network architecture
cnn = cnnx("mse","adam","linear","relu",x_shape=(10,4))
cnn.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 10, 4)]           0
# _________________________________________________________________
# flatten (Flatten)            (None, 40)                0
# _________________________________________________________________
# dense (Dense)                (None, 100)               4100
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 25)                2525
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               2600
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 40)                4040
# _________________________________________________________________
# reshape (Reshape)            (None, 10, 4)             0
# =================================================================
# Total params: 13,265
# Trainable params: 13,265
# Non-trainable params: 0
# _________________________________________________________________

# %%
def create_out(cnn1):
    """
    Creates (dim_freq, dim_phase) matrix of the output loss and the standard deviation
    """
    y_test = cnn1.predict(x_test)
    return 100*eval_loss(x_test,y_test,norm=norm2)/eval_loss(x_test,0*x_test,norm=norm2)

# %%
train1s = [(0,0.3),(3.3,np.max(xx)),(1.4,1.8)]

# %% [markdown]
# ## Training

# %%
cnns = [None]*len(train1s)
outs = [None]*len(train1s)

# %%
for i in range(len(x_test)):
    x_test[i] = x_test[i]/np.mean(x_test[i])

# %%
for i,train1 in enumerate(train1s):
    pickle, xx_train = picker(xx,*train1)
    x_train = x_test[pickle]
    cnns[i] = training(x_train = x_train,choose_cnn = cnnx, name = name, provide_cnn = False,
                 load_prev= False, num_epochs = 100,  verbose_val=1, batch_size = 16, shuffle=True, early=False,
                 loss="mse", activation0 = 'relu', activation = 'linear', optimizer = "adam",
                 dim1=(16,(3,)), dim2=(16,(3,)), x_shape = shape_)
    outs[i] = create_out(cnns[i])
# Out:
# Epoch 1/100
# 2/2 [==============================] - 1s 365ms/step - loss: 3.9123 - val_loss: 3.7369
# Epoch 2/100
# 2/2 [==============================] - 0s 29ms/step - loss: 3.6474 - val_loss: 3.5034
# Epoch 3/100
# 2/2 [==============================] - 0s 35ms/step - loss: 3.4604 - val_loss: 3.2953
# Epoch 4/100
# 2/2 [==============================] - 0s 42ms/step - loss: 3.2582 - val_loss: 3.0896
# Epoch 5/100
# 2/2 [==============================] - 0s 37ms/step - loss: 3.0171 - val_loss: 2.8649
# Epoch 6/100
# 2/2 [==============================] - 0s 41ms/step - loss: 2.8127 - val_loss: 2.6030
# Epoch 7/100
# 2/2 [==============================] - 0s 39ms/step - loss: 2.5844 - val_loss: 2.2875
# Epoch 8/100
# 2/2 [==============================] - 0s 36ms/step - loss: 2.2917 - val_loss: 1.9402
# Epoch 9/100
# 2/2 [==============================] - 0s 41ms/step - loss: 1.9720 - val_loss: 1.5577
# Epoch 10/100
# 2/2 [==============================] - 0s 39ms/step - loss: 1.6217 - val_loss: 1.1709
# Epoch 11/100
# 2/2 [==============================] - 0s 44ms/step - loss: 1.2388 - val_loss: 0.8092
# Epoch 12/100
# 2/2 [==============================] - 0s 43ms/step - loss: 0.9601 - val_loss: 0.5098
# Epoch 13/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.7566 - val_loss: 0.2964
# Epoch 14/100
# 2/2 [==============================] - 0s 51ms/step - loss: 0.7170 - val_loss: 0.1705
# Epoch 15/100
# 2/2 [==============================] - 0s 44ms/step - loss: 0.7126 - val_loss: 0.1107
# Epoch 16/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.5572 - val_loss: 0.0767
# Epoch 17/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.6197 - val_loss: 0.0489
# Epoch 18/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5779 - val_loss: 0.0293
# Epoch 19/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.5034 - val_loss: 0.0252
# Epoch 20/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.4127 - val_loss: 0.0436
# Epoch 21/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.4031 - val_loss: 0.0710
# Epoch 22/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.4056 - val_loss: 0.0971
# Epoch 23/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.4456 - val_loss: 0.1103
# Epoch 24/100
# 2/2 [==============================] - 0s 118ms/step - loss: 0.4084 - val_loss: 0.1129
# Epoch 25/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.3995 - val_loss: 0.1062
# Epoch 26/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.4007 - val_loss: 0.0908
# Epoch 27/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.3495 - val_loss: 0.0716
# Epoch 28/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.3690 - val_loss: 0.0551
# Epoch 29/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3121 - val_loss: 0.0401
# Epoch 30/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.3009 - val_loss: 0.0287
# Epoch 31/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.3814 - val_loss: 0.0218
# Epoch 32/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.3269 - val_loss: 0.0196
# Epoch 33/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.3061 - val_loss: 0.0220
# Epoch 34/100
# 2/2 [==============================] - 0s 45ms/step - loss: 0.3343 - val_loss: 0.0242
# Epoch 35/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.3062 - val_loss: 0.0261
# Epoch 36/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.2795 - val_loss: 0.0274
# Epoch 37/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2727 - val_loss: 0.0278
# Epoch 38/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3114 - val_loss: 0.0280
# Epoch 39/100
# 2/2 [==============================] - 0s 51ms/step - loss: 0.2351 - val_loss: 0.0283
# Epoch 40/100
# 2/2 [==============================] - 0s 45ms/step - loss: 0.2614 - val_loss: 0.0309
# Epoch 41/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.2770 - val_loss: 0.0323
# Epoch 42/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.3270 - val_loss: 0.0274
# Epoch 43/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.2832 - val_loss: 0.0242
# Epoch 44/100
# 2/2 [==============================] - 0s 45ms/step - loss: 0.2491 - val_loss: 0.0254
# Epoch 45/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.2178 - val_loss: 0.0287
# Epoch 46/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.2387 - val_loss: 0.0280
# Epoch 47/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.2519 - val_loss: 0.0295
# Epoch 48/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1959 - val_loss: 0.0306
# Epoch 49/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2058 - val_loss: 0.0321
# Epoch 50/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.2032 - val_loss: 0.0278
# Epoch 51/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.2981 - val_loss: 0.0200
# Epoch 52/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1625 - val_loss: 0.0172
# Epoch 53/100
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1830 - val_loss: 0.0190
# Epoch 54/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2016 - val_loss: 0.0246
# Epoch 55/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1838 - val_loss: 0.0281
# Epoch 56/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.2457 - val_loss: 0.0271
# Epoch 57/100
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1784 - val_loss: 0.0253
# Epoch 58/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1860 - val_loss: 0.0212
# Epoch 59/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1951 - val_loss: 0.0200
# Epoch 60/100
# 2/2 [==============================] - 0s 110ms/step - loss: 0.1917 - val_loss: 0.0209
# Epoch 61/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1618 - val_loss: 0.0242
# Epoch 62/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1929 - val_loss: 0.0228
# Epoch 63/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1845 - val_loss: 0.0214
# Epoch 64/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1513 - val_loss: 0.0190
# Epoch 65/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1808 - val_loss: 0.0156
# Epoch 66/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1477 - val_loss: 0.0146
# Epoch 67/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1765 - val_loss: 0.0159
# Epoch 68/100
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1615 - val_loss: 0.0187
# Epoch 69/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1893 - val_loss: 0.0190
# Epoch 70/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1809 - val_loss: 0.0185
# Epoch 71/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1303 - val_loss: 0.0259
# Epoch 72/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1611 - val_loss: 0.0286
# Epoch 73/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1683 - val_loss: 0.0241
# Epoch 74/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1276 - val_loss: 0.0237
# Epoch 75/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1401 - val_loss: 0.0251
# Epoch 76/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1442 - val_loss: 0.0210
# Epoch 77/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1270 - val_loss: 0.0154
# Epoch 78/100
# 2/2 [==============================] - 0s 51ms/step - loss: 0.1655 - val_loss: 0.0147
# Epoch 79/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1340 - val_loss: 0.0175
# Epoch 80/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1502 - val_loss: 0.0254
# Epoch 81/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1267 - val_loss: 0.0311
# Epoch 82/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1563 - val_loss: 0.0326
# Epoch 83/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.1433 - val_loss: 0.0296
# Epoch 84/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1989 - val_loss: 0.0235
# Epoch 85/100
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1026 - val_loss: 0.0210
# Epoch 86/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1213 - val_loss: 0.0194
# Epoch 87/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1611 - val_loss: 0.0139
# Epoch 88/100
# 2/2 [==============================] - 0s 119ms/step - loss: 0.1597 - val_loss: 0.0092
# Epoch 89/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.1625 - val_loss: 0.0113
# Epoch 90/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1400 - val_loss: 0.0166
# Epoch 91/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1521 - val_loss: 0.0266
# Epoch 92/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1234 - val_loss: 0.0315
# Epoch 93/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1467 - val_loss: 0.0386
# Epoch 94/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.1346 - val_loss: 0.0383
# Epoch 95/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.1038 - val_loss: 0.0266
# Epoch 96/100
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1839 - val_loss: 0.0150
# Epoch 97/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1239 - val_loss: 0.0103
# Epoch 98/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1364 - val_loss: 0.0115
# Epoch 99/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1117 - val_loss: 0.0260
# Epoch 100/100
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1237 - val_loss: 0.0404
# Epoch 1/100
# 5/5 [==============================] - 0s 33ms/step - loss: 3.0403 - val_loss: 2.6584
# Epoch 2/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.5884 - val_loss: 2.2776
# Epoch 3/100
# 5/5 [==============================] - 0s 10ms/step - loss: 2.1830 - val_loss: 1.7454
# Epoch 4/100
# 5/5 [==============================] - 0s 9ms/step - loss: 1.6385 - val_loss: 1.0609
# Epoch 5/100
# 5/5 [==============================] - 0s 10ms/step - loss: 1.0408 - val_loss: 0.4299
# Epoch 6/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.6451 - val_loss: 0.1421
# Epoch 7/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.5294 - val_loss: 0.0606
# Epoch 8/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.4646 - val_loss: 0.0391
# Epoch 9/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3400 - val_loss: 0.0788
# Epoch 10/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2896 - val_loss: 0.0852
# Epoch 11/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.2679 - val_loss: 0.0557
# Epoch 12/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2751 - val_loss: 0.0241
# Epoch 13/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.2329 - val_loss: 0.0176
# Epoch 14/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.2333 - val_loss: 0.0234
# Epoch 15/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2069 - val_loss: 0.0385
# Epoch 16/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2220 - val_loss: 0.0327
# Epoch 17/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2125 - val_loss: 0.0264
# Epoch 18/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1730 - val_loss: 0.0291
# Epoch 19/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1762 - val_loss: 0.0257
# Epoch 20/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1501 - val_loss: 0.0204
# Epoch 21/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1666 - val_loss: 0.0180
# Epoch 22/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1628 - val_loss: 0.0194
# Epoch 23/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1545 - val_loss: 0.0194
# Epoch 24/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1569 - val_loss: 0.0212
# Epoch 25/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1489 - val_loss: 0.0115
# Epoch 26/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1436 - val_loss: 0.0228
# Epoch 27/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1299 - val_loss: 0.0276
# Epoch 28/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1113 - val_loss: 0.0301
# Epoch 29/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1241 - val_loss: 0.0176
# Epoch 30/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1247 - val_loss: 0.0167
# Epoch 31/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1097 - val_loss: 0.0270
# Epoch 32/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1216 - val_loss: 0.0444
# Epoch 33/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1415 - val_loss: 0.0233
# Epoch 34/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1210 - val_loss: 0.0238
# Epoch 35/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1042 - val_loss: 0.0414
# Epoch 36/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0969 - val_loss: 0.0306
# Epoch 37/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1057 - val_loss: 0.0218
# Epoch 38/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1033 - val_loss: 0.0204
# Epoch 39/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1027 - val_loss: 0.0386
# Epoch 40/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0987 - val_loss: 0.0335
# Epoch 41/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0846 - val_loss: 0.0373
# Epoch 42/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0886 - val_loss: 0.0399
# Epoch 43/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0753 - val_loss: 0.0254
# Epoch 44/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0903 - val_loss: 0.0151
# Epoch 45/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0903 - val_loss: 0.0255
# Epoch 46/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0838 - val_loss: 0.0315
# Epoch 47/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0738 - val_loss: 0.0235
# Epoch 48/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0722 - val_loss: 0.0191
# Epoch 49/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0815 - val_loss: 0.0319
# Epoch 50/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0827 - val_loss: 0.0386
# Epoch 51/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0682 - val_loss: 0.0358
# Epoch 52/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0843 - val_loss: 0.0053
# Epoch 53/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0861 - val_loss: 0.0435
# Epoch 54/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0685 - val_loss: 0.0461
# Epoch 55/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0856 - val_loss: 0.0277
# Epoch 56/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0733 - val_loss: 0.0244
# Epoch 57/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0680 - val_loss: 0.0256
# Epoch 58/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0721 - val_loss: 0.0161
# Epoch 59/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0698 - val_loss: 0.0334
# Epoch 60/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0600 - val_loss: 0.0470
# Epoch 61/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0699 - val_loss: 0.0289
# Epoch 62/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0576 - val_loss: 0.0255
# Epoch 63/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0568 - val_loss: 0.0270
# Epoch 64/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0595 - val_loss: 0.0448
# Epoch 65/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0556 - val_loss: 0.0347
# Epoch 66/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0617 - val_loss: 0.0387
# Epoch 67/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0623 - val_loss: 0.0457
# Epoch 68/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0601 - val_loss: 0.0297
# Epoch 69/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0522 - val_loss: 0.0222
# Epoch 70/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0545 - val_loss: 0.0568
# Epoch 71/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0590 - val_loss: 0.0460
# Epoch 72/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0543 - val_loss: 0.0293
# Epoch 73/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0584 - val_loss: 0.0280
# Epoch 74/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0538 - val_loss: 0.0354
# Epoch 75/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0469 - val_loss: 0.0510
# Epoch 76/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0575 - val_loss: 0.0262
# Epoch 77/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0505 - val_loss: 0.0250
# Epoch 78/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0496 - val_loss: 0.0418
# Epoch 79/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0563 - val_loss: 0.0322
# Epoch 80/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0446 - val_loss: 0.0295
# Epoch 81/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0468 - val_loss: 0.0495
# Epoch 82/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0534 - val_loss: 0.0354
# Epoch 83/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0392 - val_loss: 0.0482
# Epoch 84/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0458 - val_loss: 0.0649
# Epoch 85/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0503 - val_loss: 0.0548
# Epoch 86/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0419 - val_loss: 0.0514
# Epoch 87/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0449 - val_loss: 0.0874
# Epoch 88/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0416 - val_loss: 0.0440
# Epoch 89/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0446 - val_loss: 0.0332
# Epoch 90/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0509 - val_loss: 0.0534
# Epoch 91/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0481 - val_loss: 0.0328
# Epoch 92/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0434 - val_loss: 0.0451
# Epoch 93/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0464 - val_loss: 0.0279
# Epoch 94/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0464 - val_loss: 0.0234
# Epoch 95/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0390 - val_loss: 0.0598
# Epoch 96/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0428 - val_loss: 0.0363
# Epoch 97/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0343 - val_loss: 0.0330
# Epoch 98/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0384 - val_loss: 0.0482
# Epoch 99/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0470 - val_loss: 0.0258
# Epoch 100/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0439 - val_loss: 0.0322
# Epoch 1/100
# 3/3 [==============================] - 0s 67ms/step - loss: 3.1548 - val_loss: 2.8395
# Epoch 2/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.8144 - val_loss: 2.6237
# Epoch 3/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.6275 - val_loss: 2.4855
# Epoch 4/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.4875 - val_loss: 2.3133
# Epoch 5/100
# 3/3 [==============================] - 0s 61ms/step - loss: 2.2716 - val_loss: 2.0890
# Epoch 6/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.0140 - val_loss: 1.8052
# Epoch 7/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.7995 - val_loss: 1.4815
# Epoch 8/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.5388 - val_loss: 1.1565
# Epoch 9/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.2690 - val_loss: 0.8645
# Epoch 10/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.0500 - val_loss: 0.6248
# Epoch 11/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8897 - val_loss: 0.4333
# Epoch 12/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7017 - val_loss: 0.2886
# Epoch 13/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.5778 - val_loss: 0.1852
# Epoch 14/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4611 - val_loss: 0.1166
# Epoch 15/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4205 - val_loss: 0.0822
# Epoch 16/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3429 - val_loss: 0.0671
# Epoch 17/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3435 - val_loss: 0.0651
# Epoch 18/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3757 - val_loss: 0.0553
# Epoch 19/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3213 - val_loss: 0.0481
# Epoch 20/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2945 - val_loss: 0.0430
# Epoch 21/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2638 - val_loss: 0.0316
# Epoch 22/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2409 - val_loss: 0.0277
# Epoch 23/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2670 - val_loss: 0.0276
# Epoch 24/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2549 - val_loss: 0.0258
# Epoch 25/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2155 - val_loss: 0.0252
# Epoch 26/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1953 - val_loss: 0.0317
# Epoch 27/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2460 - val_loss: 0.0417
# Epoch 28/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2285 - val_loss: 0.0369
# Epoch 29/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.2632 - val_loss: 0.0156
# Epoch 30/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2042 - val_loss: 0.0105
# Epoch 31/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1970 - val_loss: 0.0188
# Epoch 32/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1959 - val_loss: 0.0296
# Epoch 33/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1952 - val_loss: 0.0318
# Epoch 34/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1595 - val_loss: 0.0296
# Epoch 35/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1717 - val_loss: 0.0260
# Epoch 36/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1775 - val_loss: 0.0205
# Epoch 37/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1532 - val_loss: 0.0196
# Epoch 38/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1603 - val_loss: 0.0176
# Epoch 39/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1908 - val_loss: 0.0151
# Epoch 40/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1248 - val_loss: 0.0165
# Epoch 41/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1529 - val_loss: 0.0137
# Epoch 42/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1145 - val_loss: 0.0166
# Epoch 43/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1476 - val_loss: 0.0203
# Epoch 44/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1653 - val_loss: 0.0172
# Epoch 45/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1480 - val_loss: 0.0174
# Epoch 46/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1349 - val_loss: 0.0214
# Epoch 47/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1411 - val_loss: 0.0171
# Epoch 48/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1058 - val_loss: 0.0306
# Epoch 49/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1332 - val_loss: 0.0356
# Epoch 50/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1274 - val_loss: 0.0218
# Epoch 51/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1162 - val_loss: 0.0093
# Epoch 52/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1197 - val_loss: 0.0062
# Epoch 53/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1451 - val_loss: 0.0114
# Epoch 54/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1196 - val_loss: 0.0266
# Epoch 55/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1325 - val_loss: 0.0218
# Epoch 56/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1239 - val_loss: 0.0164
# Epoch 57/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0974 - val_loss: 0.0191
# Epoch 58/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1037 - val_loss: 0.0194
# Epoch 59/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1031 - val_loss: 0.0219
# Epoch 60/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1133 - val_loss: 0.0197
# Epoch 61/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0851 - val_loss: 0.0234
# Epoch 62/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0994 - val_loss: 0.0199
# Epoch 63/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1028 - val_loss: 0.0244
# Epoch 64/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1165 - val_loss: 0.0288
# Epoch 65/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0992 - val_loss: 0.0215
# Epoch 66/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0960 - val_loss: 0.0200
# Epoch 67/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0952 - val_loss: 0.0265
# Epoch 68/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0840 - val_loss: 0.0288
# Epoch 69/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0956 - val_loss: 0.0432
# Epoch 70/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1127 - val_loss: 0.0437
# Epoch 71/100
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0924 - val_loss: 0.0222
# Epoch 72/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0973 - val_loss: 0.0147
# Epoch 73/100
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0810 - val_loss: 0.0294
# Epoch 74/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0699 - val_loss: 0.0377
# Epoch 75/100
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0783 - val_loss: 0.0332
# Epoch 76/100
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0858 - val_loss: 0.0258
# Epoch 77/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0835 - val_loss: 0.0149
# Epoch 78/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0752 - val_loss: 0.0125
# Epoch 79/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0748 - val_loss: 0.0408
# Epoch 80/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0849 - val_loss: 0.0472
# Epoch 81/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1080 - val_loss: 0.0132
# Epoch 82/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0767 - val_loss: 0.0077
# Epoch 83/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0736 - val_loss: 0.0217
# Epoch 84/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0653 - val_loss: 0.0362
# Epoch 85/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0785 - val_loss: 0.0366
# Epoch 86/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0687 - val_loss: 0.0284
# Epoch 87/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0705 - val_loss: 0.0219
# Epoch 88/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0705 - val_loss: 0.0260
# Epoch 89/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0654 - val_loss: 0.0257
# Epoch 90/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0645 - val_loss: 0.0171
# Epoch 91/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0859 - val_loss: 0.0168
# Epoch 92/100
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0773 - val_loss: 0.0395
# Epoch 93/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0650 - val_loss: 0.0375
# Epoch 94/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0711 - val_loss: 0.0241
# Epoch 95/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0667 - val_loss: 0.0303
# Epoch 96/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0837 - val_loss: 0.0489
# Epoch 97/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0760 - val_loss: 0.0303
# Epoch 98/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0622 - val_loss: 0.0102
# Epoch 99/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0751 - val_loss: 0.0255
# Epoch 100/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0697 - val_loss: 0.0621

# %%
fig, axs = plt.subplots(nrows=3,figsize=(5.5,8),sharex=True)
for i,train1 in enumerate(train1s):
    ax = axs[i]
    out = outs[i]
    ax.plot(xx,out,".--",label="loss")
    ax.set_ylabel("loss (%)")
    ax.fill_between(*[train1],out.min(),out.max(),alpha=0.3,color="cyan", label="training")
    ax.legend()
    #ax.set_ylim(0,1.02*np.max(out))
axs[-1].set_xlabel("$J_\perp/J_{{||}}$")
axs[0].text(0,1.05,'a',weight="bold", transform = axs[0].transAxes)
axs[0].text(-0.15,0.9,"1)", transform = axs[0].transAxes)
plt.tight_layout()
for i in range(1,3):
    axs[i].text(-0.15,1.02,str(i+1) + ")", transform = axs[i].transAxes)

plt.savefig("plots/" + name + "_renormalized.png")
plt.savefig("plots/" + name + "_renormalized.pdf")
print(name)
# Out:
# 2-0

# %%
np.savez("data_results/" + name + "_data", outs = outs, xx = xx, train1s = train1s)
